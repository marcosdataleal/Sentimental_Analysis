# %% [markdown]
# # Carregando os dados

# %%
import pandas as pd

df = pd.read_csv("delivery_alimentos.csv")
df
# Out:
#        Unnamed: 0                              reviewId  \
# 0               0  2cf8d528-4be9-4582-8029-b12c7853ba9c
# 1               1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50
# 2               2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1
# 3               3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15
# 4               4  9c203cc4-289f-46cf-b55a-6332791b3b8c
# ...           ...                                   ...
# 35977       35977  785b13d8-ccc9-4629-b844-557f90d4d734
# 35978       35978  c2121839-7857-49c9-9609-27aed288d297
# 35979       35979  b5286f42-23a0-408c-9fc4-5c0f069e950a
# 35980       35980  b31c7352-1b90-4caf-81d7-e0e2ae9b44d5
# 35981       35981  befb72c1-8a35-4c09-8094-44a2278cd8a3
#
#                      userName  \
# 0             Daniela Aguilar
# 1      Arlan Cruz (Miguelito)
# 2             Gabriel Liondas
# 3                Ester Araújo
# 4                     Adr_Alv
# ...                       ...
# 35977            Lais De Lima
# 35978             Marta Silva
# 35979               Bp Santos
# 35980             Mauro Cesar
# 35981          Fernando Silva
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 35977  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35978  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35979  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35980  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35981  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...      1
# 1      Informações do produto e imagens sem clareza. ...      1
# 2      Uso o aplicativo a um bom tempo, porém, tive u...      1
# 3      Não tem mais preocupação com qualidade. Os ent...      1
# 4      Não aparece mais cupons, a mais de 7 meses par...      1
# ...                                                  ...    ...
# 35977                            Muito bom amei esse app      5
# 35978                                          Muito bom      5
# 35979             Ótimo pra todo momento www.aiqfome.com      5
# 35980                                             Top 🤝🏻      5
# 35981  Incrível , sempre tem bons resultados e as mel...      5
#
#        thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 0                252              9.223.0  2023-09-09 02:48:00          NaN
# 1                173              9.223.0  2023-09-10 00:24:00          NaN
# 2                 12              9.222.1  2023-09-09 16:46:25          NaN
# 3                 32              9.221.0  2023-08-31 21:14:46          NaN
# 4                 14              9.222.1  2023-09-08 14:40:36          NaN
# ...              ...                  ...                  ...          ...
# 35977              0               10.0.0  2023-07-15 18:45:03          NaN
# 35978              0               10.0.0  2023-07-15 15:56:29          NaN
# 35979              0               10.0.0  2023-07-15 03:09:38          NaN
# 35980              0               10.0.0  2023-07-15 00:42:34          NaN
# 35981              0                  NaN  2023-07-15 00:06:39          NaN
#
#       repliedAt appVersion      sortOrder                  appId
# 0           NaN    9.223.0  most_relevant  br.com.brainweb.ifood
# 1           NaN    9.223.0  most_relevant  br.com.brainweb.ifood
# 2           NaN    9.222.1  most_relevant  br.com.brainweb.ifood
# 3           NaN    9.221.0  most_relevant  br.com.brainweb.ifood
# 4           NaN    9.222.1  most_relevant  br.com.brainweb.ifood
# ...         ...        ...            ...                    ...
# 35977       NaN     10.0.0         newest    com.vanuatu.aiqfome
# 35978       NaN     10.0.0         newest    com.vanuatu.aiqfome
# 35979       NaN     10.0.0         newest    com.vanuatu.aiqfome
# 35980       NaN     10.0.0         newest    com.vanuatu.aiqfome
# 35981       NaN        NaN         newest    com.vanuatu.aiqfome
#
# [35982 rows x 14 columns]

# %% [markdown]
# # Análise dos dados

# %% [markdown]
# ## Verificando nulos

# %%
def check_nulls():
  number_nulls = df.isnull().sum()
  print("Número de nulos por coluna:\n")
  print(number_nulls, '\n')

# %%
check_nulls()
# Out:
# Número de nulos por coluna:
#
# Unnamed: 0                  0
# reviewId                    0
# userName                    0
# userImage                   0
# content                     0
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion     3361
# at                          0
# replyContent            27020
# repliedAt               27020
# appVersion               3361
# sortOrder                   0
# appId                       0
# dtype: int64

# %% [markdown]
# ## Contando palavras

# %%
df['word_count'] = df['content'].str.split().apply(len)
df['word_count']
# Out:
# 0        81
# 1        77
# 2        71
# 3        55
# 4        95
#          ..
# 35977     5
# 35978     2
# 35979     5
# 35980     2
# 35981    28
# Name: word_count, Length: 35982, dtype: int64

# %%
df['word_count'].min()
# Out:
# 1

# %%
df['word_count'].mean()
# Out:
# 28.090712022678005

# %%
df['word_count'].max()
# Out:
# 350

# %%
import seaborn as sns

sns.histplot(data = df, x = 'word_count')
# Out:
# <Axes: xlabel='word_count', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

def count_words(text_column):
  df['word_count'] = df[text_column].str.split().apply(len)

  min = df['word_count'].min()
  mean = df['word_count'].mean()
  max = df['word_count'].max()

  print("O número mínimo de palavras no dataset é:", min)
  print("A média de palavras no dataset é:", mean)
  print("O número máximo de palavras no dataset é:", max)

  print("\nHistograma da frequência do número de palavras")
  sns.histplot(data = df, x = 'word_count')
  plt.show()

# %%
count_words('content')
# Out:
# O número mínimo de palavras no dataset é: 1
# A média de palavras no dataset é: 28.090712022678005
# O número máximo de palavras no dataset é: 350
#
# Histograma da frequência do número de palavras

# %% [markdown]
# ## Verificando a distribuição dos scores

# %%
score_counts = df['score'].value_counts()
score_counts
# Out:
# 4    9000
# 5    9000
# 1    5994
# 2    5994
# 3    5994
# Name: score, dtype: int64

# %%
sns.histplot(data = df, x = 'score', discrete = True)
# Out:
# <Axes: xlabel='score', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

plt.pie(score_counts, labels = score_counts.index, autopct = '%1.1f%%')
plt.title("Distribuição dos scores")
plt.axis('equal')
plt.show()

# %%
def class_distribution(class_column):
  class_counts = df[class_column].value_counts()

  print("Número de instâncias por classe")
  print(class_counts)

  print("\nHistograma da distribuição das classes")
  sns.histplot(data = df, x = class_column, discrete = True)
  plt.show()

  print("\nGráfico de pizza da distribuição das classes")
  plt.pie(class_counts, labels = class_counts.index, autopct = '%1.1f%%')
  plt.title("Distribuição das classes")
  plt.axis('equal')
  plt.show()

# %%
class_distribution('score')
# Out:
# Número de instâncias por classe
# 4    9000
# 5    9000
# 1    5994
# 2    5994
# 3    5994
# Name: score, dtype: int64
#
# Histograma da distribuição das classes
# Gráfico de pizza da distribuição das classes

# %% [markdown]
# ## Palavras mais frequentes

# %%
from collections import Counter

all_text = ' '.join(df['content'])
words = all_text.split()
word_count = Counter(words)

number_words = 10

most_common_words = word_count.most_common(number_words)
most_common_words_df = pd.DataFrame(most_common_words, columns = ['Palavra', 'Frequência'])
most_common_words_df
# Out:
#   Palavra  Frequência
# 0       o       34379
# 1      de       32419
# 2       e       30626
# 3     que       24527
# 4     não       22092
# 5       a       19925
# 6       é       12873
# 7     com       10660
# 8      do       10532
# 9      um        9547

# %%
def most_frequency_words(df, text_column, number_words = 10):
  all_text = ' '.join(df[text_column])
  words = all_text.split()
  word_count = Counter(words)

  print("\nPalavras mais frequentes")
  most_common_words = word_count.most_common(number_words)
  most_common_words_df = pd.DataFrame(most_common_words, columns = ['Palavra', 'Frequência'])
  display(most_common_words_df)

# %%
most_frequency_words(df, 'content')
# Out:
# Palavras mais frequentes
#   Palavra  Frequência
# 0       o       34379
# 1      de       32419
# 2       e       30626
# 3     que       24527
# 4     não       22092
# 5       a       19925
# 6       é       12873
# 7     com       10660
# 8      do       10532
# 9      um        9547

# %% [markdown]
# ## Palavras mais frequentes por classe

# %%
for class_label in df['score'].unique():
  class_df = df[df['score'] == class_label]

  print("\nPalavras mais frequentes para a classe", class_label)
  most_frequency_words(class_df, 'content')
# Out:
# Palavras mais frequentes para a classe 1
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       o        8542
# 1       e        7476
# 2      de        6939
# 3     não        6575
# 4     que        5650
# 5       a        4309
# 6     com        2598
# 7      um        2510
# 8      no        2379
# 9      do        2304
# Palavras mais frequentes para a classe 2
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       o        7796
# 1      de        6708
# 2       e        6304
# 3     não        5618
# 4     que        5422
# 5       a        4260
# 6       é        2541
# 7     com        2266
# 8      do        2175
# 9      no        2090
# Palavras mais frequentes para a classe 3
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       o        6622
# 1      de        6108
# 2       e        5261
# 3     que        4784
# 4     não        4261
# 5       a        4069
# 6       é        2659
# 7      do        2026
# 8     com        1896
# 9      no        1882
# Palavras mais frequentes para a classe 4
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0      de        7215
# 1       o        6784
# 2       e        5794
# 3     que        5161
# 4       a        4445
# 5     não        3844
# 6       é        3429
# 7      do        2372
# 8   muito        2258
# 9    mais        2037
# Palavras mais frequentes para a classe 5
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       e        5791
# 1      de        5449
# 2       o        4635
# 3     que        3510
# 4       a        2842
# 5   muito        2435
# 6       é        2119
# 7     com        1903
# 8     não        1794
# 9      do        1655

# %%
def most_frequency_words_by_class(text_column, class_column):
  for class_label in df[class_column].unique():
    class_df = df[df[class_column] == class_label]

    print("\nPalavras mais frequentes para a classe", class_label)
    most_frequency_words(class_df, text_column)

# %%
most_frequency_words_by_class('content', 'score')
# Out:
# Palavras mais frequentes para a classe 1
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       o        8542
# 1       e        7476
# 2      de        6939
# 3     não        6575
# 4     que        5650
# 5       a        4309
# 6     com        2598
# 7      um        2510
# 8      no        2379
# 9      do        2304
# Palavras mais frequentes para a classe 2
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       o        7796
# 1      de        6708
# 2       e        6304
# 3     não        5618
# 4     que        5422
# 5       a        4260
# 6       é        2541
# 7     com        2266
# 8      do        2175
# 9      no        2090
# Palavras mais frequentes para a classe 3
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       o        6622
# 1      de        6108
# 2       e        5261
# 3     que        4784
# 4     não        4261
# 5       a        4069
# 6       é        2659
# 7      do        2026
# 8     com        1896
# 9      no        1882
# Palavras mais frequentes para a classe 4
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0      de        7215
# 1       o        6784
# 2       e        5794
# 3     que        5161
# 4       a        4445
# 5     não        3844
# 6       é        3429
# 7      do        2372
# 8   muito        2258
# 9    mais        2037
# Palavras mais frequentes para a classe 5
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       e        5791
# 1      de        5449
# 2       o        4635
# 3     que        3510
# 4       a        2842
# 5   muito        2435
# 6       é        2119
# 7     com        1903
# 8     não        1794
# 9      do        1655

# %% [markdown]
# ## WordCloud

# %%
from wordcloud import WordCloud

all_text = ' '.join(df['content'])

wordcloud = WordCloud(width = 800, height = 400, background_color = 'white').generate(all_text)

plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
def word_cloud(text_column):
  all_text = ' '.join(df[text_column])

  print("\nWordCloud")
  wordcloud = WordCloud(width = 800, height = 400, background_color = 'white').generate(all_text)

  plt.figure(figsize=(10,5))
  plt.imshow(wordcloud, interpolation = 'bilinear')
  plt.axis('off')
  plt.show()

# %%
word_cloud('content')
# Out:
# WordCloud

# %% [markdown]
# ## Juntando todas as funções de análise de dados

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from wordcloud import WordCloud

def data_analytics(df, text_column, class_column):
  check_nulls()
  count_words(text_column)
  class_distribution(class_column)
  most_frequency_words(df, text_column)
  most_frequency_words_by_class(text_column, class_column)
  word_cloud(text_column)

# %%
data_analytics(df, 'content', 'score')
# Out:
# Número de nulos por coluna:
#
# Unnamed: 0                  0
# reviewId                    0
# userName                    0
# userImage                   0
# content                     0
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion     3361
# at                          0
# replyContent            27020
# repliedAt               27020
# appVersion               3361
# sortOrder                   0
# appId                       0
# word_count                  0
# dtype: int64
#
# O número mínimo de palavras no dataset é: 1
# A média de palavras no dataset é: 28.090712022678005
# O número máximo de palavras no dataset é: 350
#
# Histograma da frequência do número de palavras
# Número de instâncias por classe
# 4    9000
# 5    9000
# 1    5994
# 2    5994
# 3    5994
# Name: score, dtype: int64
#
# Histograma da distribuição das classes
# Gráfico de pizza da distribuição das classes
# Palavras mais frequentes
#   Palavra  Frequência
# 0       o       34379
# 1      de       32419
# 2       e       30626
# 3     que       24527
# 4     não       22092
# 5       a       19925
# 6       é       12873
# 7     com       10660
# 8      do       10532
# 9      um        9547
# Palavras mais frequentes para a classe 1
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       o        8542
# 1       e        7476
# 2      de        6939
# 3     não        6575
# 4     que        5650
# 5       a        4309
# 6     com        2598
# 7      um        2510
# 8      no        2379
# 9      do        2304
# Palavras mais frequentes para a classe 2
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       o        7796
# 1      de        6708
# 2       e        6304
# 3     não        5618
# 4     que        5422
# 5       a        4260
# 6       é        2541
# 7     com        2266
# 8      do        2175
# 9      no        2090
# Palavras mais frequentes para a classe 3
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       o        6622
# 1      de        6108
# 2       e        5261
# 3     que        4784
# 4     não        4261
# 5       a        4069
# 6       é        2659
# 7      do        2026
# 8     com        1896
# 9      no        1882
# Palavras mais frequentes para a classe 4
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0      de        7215
# 1       o        6784
# 2       e        5794
# 3     que        5161
# 4       a        4445
# 5     não        3844
# 6       é        3429
# 7      do        2372
# 8   muito        2258
# 9    mais        2037
# Palavras mais frequentes para a classe 5
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0       e        5791
# 1      de        5449
# 2       o        4635
# 3     que        3510
# 4       a        2842
# 5   muito        2435
# 6       é        2119
# 7     com        1903
# 8     não        1794
# 9      do        1655
# WordCloud

# %% [markdown]
# # Pré-processamento

# %% [markdown]
# ## Removendo textos longos

# %%
df = df[df['word_count'] <= 150]
df
# Out:
#        Unnamed: 0                              reviewId  \
# 0               0  2cf8d528-4be9-4582-8029-b12c7853ba9c
# 1               1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50
# 2               2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1
# 3               3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15
# 4               4  9c203cc4-289f-46cf-b55a-6332791b3b8c
# ...           ...                                   ...
# 35977       35977  785b13d8-ccc9-4629-b844-557f90d4d734
# 35978       35978  c2121839-7857-49c9-9609-27aed288d297
# 35979       35979  b5286f42-23a0-408c-9fc4-5c0f069e950a
# 35980       35980  b31c7352-1b90-4caf-81d7-e0e2ae9b44d5
# 35981       35981  befb72c1-8a35-4c09-8094-44a2278cd8a3
#
#                      userName  \
# 0             Daniela Aguilar
# 1      Arlan Cruz (Miguelito)
# 2             Gabriel Liondas
# 3                Ester Araújo
# 4                     Adr_Alv
# ...                       ...
# 35977            Lais De Lima
# 35978             Marta Silva
# 35979               Bp Santos
# 35980             Mauro Cesar
# 35981          Fernando Silva
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 35977  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35978  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35979  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35980  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35981  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...      1
# 1      Informações do produto e imagens sem clareza. ...      1
# 2      Uso o aplicativo a um bom tempo, porém, tive u...      1
# 3      Não tem mais preocupação com qualidade. Os ent...      1
# 4      Não aparece mais cupons, a mais de 7 meses par...      1
# ...                                                  ...    ...
# 35977                            Muito bom amei esse app      5
# 35978                                          Muito bom      5
# 35979             Ótimo pra todo momento www.aiqfome.com      5
# 35980                                             Top 🤝🏻      5
# 35981  Incrível , sempre tem bons resultados e as mel...      5
#
#        thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 0                252              9.223.0  2023-09-09 02:48:00          NaN
# 1                173              9.223.0  2023-09-10 00:24:00          NaN
# 2                 12              9.222.1  2023-09-09 16:46:25          NaN
# 3                 32              9.221.0  2023-08-31 21:14:46          NaN
# 4                 14              9.222.1  2023-09-08 14:40:36          NaN
# ...              ...                  ...                  ...          ...
# 35977              0               10.0.0  2023-07-15 18:45:03          NaN
# 35978              0               10.0.0  2023-07-15 15:56:29          NaN
# 35979              0               10.0.0  2023-07-15 03:09:38          NaN
# 35980              0               10.0.0  2023-07-15 00:42:34          NaN
# 35981              0                  NaN  2023-07-15 00:06:39          NaN
#
#       repliedAt appVersion      sortOrder                  appId  word_count
# 0           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          81
# 1           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          77
# 2           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          71
# 3           NaN    9.221.0  most_relevant  br.com.brainweb.ifood          55
# 4           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          95
# ...         ...        ...            ...                    ...         ...
# 35977       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35978       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35979       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35980       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35981       NaN        NaN         newest    com.vanuatu.aiqfome          28
#
# [35977 rows x 15 columns]

# %% [markdown]
# ## Removendo emojis

# %%
import re

def remove_emojis(text):
  emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # símbolos & pictogramas
                           u"\U0001F680-\U0001F6FF"  # transportes e símbolos
                           u"\U0001F700-\U0001F77F"  # símbolos alquímicos
                           u"\U0001F780-\U0001F7FF"  # símbolos geométricos
                           u"\U0001F800-\U0001F8FF"  # suplemento de símbolos e pictogramas
                           u"\U0001F900-\U0001F9FF"  # emoticons adicionais
                           u"\U0001FA00-\U0001FA6F"  # objetos diversos
                           u"\U0001FA70-\U0001FAFF"  # símbolos diversos
                           u"\U0001F004"              # símbolo de cartão de jogo
                           u"\U0001F0CF"              # símbolo do baralho
                           u"\U0001F170-\U0001F251"  # emojis de letras (variante)
                           u"\U00002702-\U000027B0"  # símbolos diversos
                           u"\U000024C2-\U0001F251"
                           "]+", flags = re.UNICODE)
  return emoji_pattern.sub(r'', text)

df['removed_emoji'] = df['content'].apply(remove_emojis)
df
# Out:
# <ipython-input-30-77b872aad81e>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['removed_emoji'] = df['content'].apply(remove_emojis)
#        Unnamed: 0                              reviewId  \
# 0               0  2cf8d528-4be9-4582-8029-b12c7853ba9c
# 1               1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50
# 2               2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1
# 3               3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15
# 4               4  9c203cc4-289f-46cf-b55a-6332791b3b8c
# ...           ...                                   ...
# 35977       35977  785b13d8-ccc9-4629-b844-557f90d4d734
# 35978       35978  c2121839-7857-49c9-9609-27aed288d297
# 35979       35979  b5286f42-23a0-408c-9fc4-5c0f069e950a
# 35980       35980  b31c7352-1b90-4caf-81d7-e0e2ae9b44d5
# 35981       35981  befb72c1-8a35-4c09-8094-44a2278cd8a3
#
#                      userName  \
# 0             Daniela Aguilar
# 1      Arlan Cruz (Miguelito)
# 2             Gabriel Liondas
# 3                Ester Araújo
# 4                     Adr_Alv
# ...                       ...
# 35977            Lais De Lima
# 35978             Marta Silva
# 35979               Bp Santos
# 35980             Mauro Cesar
# 35981          Fernando Silva
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 35977  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35978  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35979  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35980  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35981  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...      1
# 1      Informações do produto e imagens sem clareza. ...      1
# 2      Uso o aplicativo a um bom tempo, porém, tive u...      1
# 3      Não tem mais preocupação com qualidade. Os ent...      1
# 4      Não aparece mais cupons, a mais de 7 meses par...      1
# ...                                                  ...    ...
# 35977                            Muito bom amei esse app      5
# 35978                                          Muito bom      5
# 35979             Ótimo pra todo momento www.aiqfome.com      5
# 35980                                             Top 🤝🏻      5
# 35981  Incrível , sempre tem bons resultados e as mel...      5
#
#        thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 0                252              9.223.0  2023-09-09 02:48:00          NaN
# 1                173              9.223.0  2023-09-10 00:24:00          NaN
# 2                 12              9.222.1  2023-09-09 16:46:25          NaN
# 3                 32              9.221.0  2023-08-31 21:14:46          NaN
# 4                 14              9.222.1  2023-09-08 14:40:36          NaN
# ...              ...                  ...                  ...          ...
# 35977              0               10.0.0  2023-07-15 18:45:03          NaN
# 35978              0               10.0.0  2023-07-15 15:56:29          NaN
# 35979              0               10.0.0  2023-07-15 03:09:38          NaN
# 35980              0               10.0.0  2023-07-15 00:42:34          NaN
# 35981              0                  NaN  2023-07-15 00:06:39          NaN
#
#       repliedAt appVersion      sortOrder                  appId  word_count  \
# 0           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          81
# 1           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          77
# 2           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          71
# 3           NaN    9.221.0  most_relevant  br.com.brainweb.ifood          55
# 4           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          95
# ...         ...        ...            ...                    ...         ...
# 35977       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35978       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35979       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35980       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35981       NaN        NaN         newest    com.vanuatu.aiqfome          28
#
#                                            removed_emoji
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979             Ótimo pra todo momento www.aiqfome.com
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
# [35977 rows x 16 columns]

# %% [markdown]
# ## Removendo links

# %%
def remove_link(text):
  text_without_links = re.sub(r'www\S+|http\S+|ftp\S+', '', text)
  return text_without_links

df['removed_links'] = df['removed_emoji'].apply(remove_link)
df
# Out:
# <ipython-input-31-6a79b79b117c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['removed_links'] = df['removed_emoji'].apply(remove_link)
#        Unnamed: 0                              reviewId  \
# 0               0  2cf8d528-4be9-4582-8029-b12c7853ba9c
# 1               1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50
# 2               2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1
# 3               3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15
# 4               4  9c203cc4-289f-46cf-b55a-6332791b3b8c
# ...           ...                                   ...
# 35977       35977  785b13d8-ccc9-4629-b844-557f90d4d734
# 35978       35978  c2121839-7857-49c9-9609-27aed288d297
# 35979       35979  b5286f42-23a0-408c-9fc4-5c0f069e950a
# 35980       35980  b31c7352-1b90-4caf-81d7-e0e2ae9b44d5
# 35981       35981  befb72c1-8a35-4c09-8094-44a2278cd8a3
#
#                      userName  \
# 0             Daniela Aguilar
# 1      Arlan Cruz (Miguelito)
# 2             Gabriel Liondas
# 3                Ester Araújo
# 4                     Adr_Alv
# ...                       ...
# 35977            Lais De Lima
# 35978             Marta Silva
# 35979               Bp Santos
# 35980             Mauro Cesar
# 35981          Fernando Silva
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 35977  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35978  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35979  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35980  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35981  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...      1
# 1      Informações do produto e imagens sem clareza. ...      1
# 2      Uso o aplicativo a um bom tempo, porém, tive u...      1
# 3      Não tem mais preocupação com qualidade. Os ent...      1
# 4      Não aparece mais cupons, a mais de 7 meses par...      1
# ...                                                  ...    ...
# 35977                            Muito bom amei esse app      5
# 35978                                          Muito bom      5
# 35979             Ótimo pra todo momento www.aiqfome.com      5
# 35980                                             Top 🤝🏻      5
# 35981  Incrível , sempre tem bons resultados e as mel...      5
#
#        thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 0                252              9.223.0  2023-09-09 02:48:00          NaN
# 1                173              9.223.0  2023-09-10 00:24:00          NaN
# 2                 12              9.222.1  2023-09-09 16:46:25          NaN
# 3                 32              9.221.0  2023-08-31 21:14:46          NaN
# 4                 14              9.222.1  2023-09-08 14:40:36          NaN
# ...              ...                  ...                  ...          ...
# 35977              0               10.0.0  2023-07-15 18:45:03          NaN
# 35978              0               10.0.0  2023-07-15 15:56:29          NaN
# 35979              0               10.0.0  2023-07-15 03:09:38          NaN
# 35980              0               10.0.0  2023-07-15 00:42:34          NaN
# 35981              0                  NaN  2023-07-15 00:06:39          NaN
#
#       repliedAt appVersion      sortOrder                  appId  word_count  \
# 0           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          81
# 1           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          77
# 2           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          71
# 3           NaN    9.221.0  most_relevant  br.com.brainweb.ifood          55
# 4           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          95
# ...         ...        ...            ...                    ...         ...
# 35977       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35978       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35979       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35980       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35981       NaN        NaN         newest    com.vanuatu.aiqfome          28
#
#                                            removed_emoji  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979             Ótimo pra todo momento www.aiqfome.com
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                            removed_links
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979                            Ótimo pra todo momento
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
# [35977 rows x 17 columns]

# %% [markdown]
# ## Tokenizando

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')

def tokenize_text(text):
  tokens = word_tokenize(text)
  return tokens

df['tokens'] = df['removed_links'].apply(tokenize_text)
df
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# <ipython-input-32-2db58ec13d80>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tokens'] = df['removed_links'].apply(tokenize_text)
#        Unnamed: 0                              reviewId  \
# 0               0  2cf8d528-4be9-4582-8029-b12c7853ba9c
# 1               1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50
# 2               2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1
# 3               3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15
# 4               4  9c203cc4-289f-46cf-b55a-6332791b3b8c
# ...           ...                                   ...
# 35977       35977  785b13d8-ccc9-4629-b844-557f90d4d734
# 35978       35978  c2121839-7857-49c9-9609-27aed288d297
# 35979       35979  b5286f42-23a0-408c-9fc4-5c0f069e950a
# 35980       35980  b31c7352-1b90-4caf-81d7-e0e2ae9b44d5
# 35981       35981  befb72c1-8a35-4c09-8094-44a2278cd8a3
#
#                      userName  \
# 0             Daniela Aguilar
# 1      Arlan Cruz (Miguelito)
# 2             Gabriel Liondas
# 3                Ester Araújo
# 4                     Adr_Alv
# ...                       ...
# 35977            Lais De Lima
# 35978             Marta Silva
# 35979               Bp Santos
# 35980             Mauro Cesar
# 35981          Fernando Silva
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 35977  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35978  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35979  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35980  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35981  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...      1
# 1      Informações do produto e imagens sem clareza. ...      1
# 2      Uso o aplicativo a um bom tempo, porém, tive u...      1
# 3      Não tem mais preocupação com qualidade. Os ent...      1
# 4      Não aparece mais cupons, a mais de 7 meses par...      1
# ...                                                  ...    ...
# 35977                            Muito bom amei esse app      5
# 35978                                          Muito bom      5
# 35979             Ótimo pra todo momento www.aiqfome.com      5
# 35980                                             Top 🤝🏻      5
# 35981  Incrível , sempre tem bons resultados e as mel...      5
#
#        thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 0                252              9.223.0  2023-09-09 02:48:00          NaN
# 1                173              9.223.0  2023-09-10 00:24:00          NaN
# 2                 12              9.222.1  2023-09-09 16:46:25          NaN
# 3                 32              9.221.0  2023-08-31 21:14:46          NaN
# 4                 14              9.222.1  2023-09-08 14:40:36          NaN
# ...              ...                  ...                  ...          ...
# 35977              0               10.0.0  2023-07-15 18:45:03          NaN
# 35978              0               10.0.0  2023-07-15 15:56:29          NaN
# 35979              0               10.0.0  2023-07-15 03:09:38          NaN
# 35980              0               10.0.0  2023-07-15 00:42:34          NaN
# 35981              0                  NaN  2023-07-15 00:06:39          NaN
#
#       repliedAt appVersion      sortOrder                  appId  word_count  \
# 0           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          81
# 1           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          77
# 2           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          71
# 3           NaN    9.221.0  most_relevant  br.com.brainweb.ifood          55
# 4           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          95
# ...         ...        ...            ...                    ...         ...
# 35977       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35978       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35979       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35980       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35981       NaN        NaN         newest    com.vanuatu.aiqfome          28
#
#                                            removed_emoji  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979             Ótimo pra todo momento www.aiqfome.com
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                            removed_links  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979                            Ótimo pra todo momento
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                                   tokens
# 0      [Fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [Informações, do, produto, e, imagens, sem, cl...
# 2      [Uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [Não, tem, mais, preocupação, com, qualidade, ...
# 4      [Não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [Muito, bom, amei, esse, app]
# 35978                                       [Muito, bom]
# 35979                        [Ótimo, pra, todo, momento]
# 35980                                              [Top]
# 35981  [Incrível, ,, sempre, tem, bons, resultados, e...
#
# [35977 rows x 18 columns]

# %% [markdown]
# ## Convertendo para minúscula

# %%
def lowercase(tokens):
  lowercase_tokens = [token.lower() for token in tokens]
  return lowercase_tokens

df['tokens_lowercase'] = df['tokens'].apply(lowercase)
df
# Out:
# <ipython-input-33-5968a5a54e5e>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tokens_lowercase'] = df['tokens'].apply(lowercase)
#        Unnamed: 0                              reviewId  \
# 0               0  2cf8d528-4be9-4582-8029-b12c7853ba9c
# 1               1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50
# 2               2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1
# 3               3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15
# 4               4  9c203cc4-289f-46cf-b55a-6332791b3b8c
# ...           ...                                   ...
# 35977       35977  785b13d8-ccc9-4629-b844-557f90d4d734
# 35978       35978  c2121839-7857-49c9-9609-27aed288d297
# 35979       35979  b5286f42-23a0-408c-9fc4-5c0f069e950a
# 35980       35980  b31c7352-1b90-4caf-81d7-e0e2ae9b44d5
# 35981       35981  befb72c1-8a35-4c09-8094-44a2278cd8a3
#
#                      userName  \
# 0             Daniela Aguilar
# 1      Arlan Cruz (Miguelito)
# 2             Gabriel Liondas
# 3                Ester Araújo
# 4                     Adr_Alv
# ...                       ...
# 35977            Lais De Lima
# 35978             Marta Silva
# 35979               Bp Santos
# 35980             Mauro Cesar
# 35981          Fernando Silva
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 35977  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35978  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35979  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35980  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35981  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...      1
# 1      Informações do produto e imagens sem clareza. ...      1
# 2      Uso o aplicativo a um bom tempo, porém, tive u...      1
# 3      Não tem mais preocupação com qualidade. Os ent...      1
# 4      Não aparece mais cupons, a mais de 7 meses par...      1
# ...                                                  ...    ...
# 35977                            Muito bom amei esse app      5
# 35978                                          Muito bom      5
# 35979             Ótimo pra todo momento www.aiqfome.com      5
# 35980                                             Top 🤝🏻      5
# 35981  Incrível , sempre tem bons resultados e as mel...      5
#
#        thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 0                252              9.223.0  2023-09-09 02:48:00          NaN
# 1                173              9.223.0  2023-09-10 00:24:00          NaN
# 2                 12              9.222.1  2023-09-09 16:46:25          NaN
# 3                 32              9.221.0  2023-08-31 21:14:46          NaN
# 4                 14              9.222.1  2023-09-08 14:40:36          NaN
# ...              ...                  ...                  ...          ...
# 35977              0               10.0.0  2023-07-15 18:45:03          NaN
# 35978              0               10.0.0  2023-07-15 15:56:29          NaN
# 35979              0               10.0.0  2023-07-15 03:09:38          NaN
# 35980              0               10.0.0  2023-07-15 00:42:34          NaN
# 35981              0                  NaN  2023-07-15 00:06:39          NaN
#
#       repliedAt appVersion      sortOrder                  appId  word_count  \
# 0           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          81
# 1           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          77
# 2           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          71
# 3           NaN    9.221.0  most_relevant  br.com.brainweb.ifood          55
# 4           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          95
# ...         ...        ...            ...                    ...         ...
# 35977       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35978       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35979       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35980       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35981       NaN        NaN         newest    com.vanuatu.aiqfome          28
#
#                                            removed_emoji  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979             Ótimo pra todo momento www.aiqfome.com
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                            removed_links  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979                            Ótimo pra todo momento
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                                   tokens  \
# 0      [Fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [Informações, do, produto, e, imagens, sem, cl...
# 2      [Uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [Não, tem, mais, preocupação, com, qualidade, ...
# 4      [Não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [Muito, bom, amei, esse, app]
# 35978                                       [Muito, bom]
# 35979                        [Ótimo, pra, todo, momento]
# 35980                                              [Top]
# 35981  [Incrível, ,, sempre, tem, bons, resultados, e...
#
#                                         tokens_lowercase
# 0      [fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [informações, do, produto, e, imagens, sem, cl...
# 2      [uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [não, tem, mais, preocupação, com, qualidade, ...
# 4      [não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [muito, bom, amei, esse, app]
# 35978                                       [muito, bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, ,, sempre, tem, bons, resultados, e...
#
# [35977 rows x 19 columns]

# %% [markdown]
# ## Removendo pontuações

# %%
import string

string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(tokens):
  tokens_without_punctuation = [token for token in tokens if token not in string.punctuation]
  return tokens_without_punctuation

df['tokens_without_punctuation'] = df['tokens_lowercase'].apply(remove_punctuation)
df
# Out:
# <ipython-input-35-5fe18e67a5f8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tokens_without_punctuation'] = df['tokens_lowercase'].apply(remove_punctuation)
#        Unnamed: 0                              reviewId  \
# 0               0  2cf8d528-4be9-4582-8029-b12c7853ba9c
# 1               1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50
# 2               2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1
# 3               3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15
# 4               4  9c203cc4-289f-46cf-b55a-6332791b3b8c
# ...           ...                                   ...
# 35977       35977  785b13d8-ccc9-4629-b844-557f90d4d734
# 35978       35978  c2121839-7857-49c9-9609-27aed288d297
# 35979       35979  b5286f42-23a0-408c-9fc4-5c0f069e950a
# 35980       35980  b31c7352-1b90-4caf-81d7-e0e2ae9b44d5
# 35981       35981  befb72c1-8a35-4c09-8094-44a2278cd8a3
#
#                      userName  \
# 0             Daniela Aguilar
# 1      Arlan Cruz (Miguelito)
# 2             Gabriel Liondas
# 3                Ester Araújo
# 4                     Adr_Alv
# ...                       ...
# 35977            Lais De Lima
# 35978             Marta Silva
# 35979               Bp Santos
# 35980             Mauro Cesar
# 35981          Fernando Silva
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 35977  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35978  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35979  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35980  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35981  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...      1
# 1      Informações do produto e imagens sem clareza. ...      1
# 2      Uso o aplicativo a um bom tempo, porém, tive u...      1
# 3      Não tem mais preocupação com qualidade. Os ent...      1
# 4      Não aparece mais cupons, a mais de 7 meses par...      1
# ...                                                  ...    ...
# 35977                            Muito bom amei esse app      5
# 35978                                          Muito bom      5
# 35979             Ótimo pra todo momento www.aiqfome.com      5
# 35980                                             Top 🤝🏻      5
# 35981  Incrível , sempre tem bons resultados e as mel...      5
#
#        thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 0                252              9.223.0  2023-09-09 02:48:00          NaN
# 1                173              9.223.0  2023-09-10 00:24:00          NaN
# 2                 12              9.222.1  2023-09-09 16:46:25          NaN
# 3                 32              9.221.0  2023-08-31 21:14:46          NaN
# 4                 14              9.222.1  2023-09-08 14:40:36          NaN
# ...              ...                  ...                  ...          ...
# 35977              0               10.0.0  2023-07-15 18:45:03          NaN
# 35978              0               10.0.0  2023-07-15 15:56:29          NaN
# 35979              0               10.0.0  2023-07-15 03:09:38          NaN
# 35980              0               10.0.0  2023-07-15 00:42:34          NaN
# 35981              0                  NaN  2023-07-15 00:06:39          NaN
#
#       repliedAt appVersion      sortOrder                  appId  word_count  \
# 0           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          81
# 1           NaN    9.223.0  most_relevant  br.com.brainweb.ifood          77
# 2           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          71
# 3           NaN    9.221.0  most_relevant  br.com.brainweb.ifood          55
# 4           NaN    9.222.1  most_relevant  br.com.brainweb.ifood          95
# ...         ...        ...            ...                    ...         ...
# 35977       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35978       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35979       NaN     10.0.0         newest    com.vanuatu.aiqfome           5
# 35980       NaN     10.0.0         newest    com.vanuatu.aiqfome           2
# 35981       NaN        NaN         newest    com.vanuatu.aiqfome          28
#
#                                            removed_emoji  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979             Ótimo pra todo momento www.aiqfome.com
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                            removed_links  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979                            Ótimo pra todo momento
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                                   tokens  \
# 0      [Fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [Informações, do, produto, e, imagens, sem, cl...
# 2      [Uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [Não, tem, mais, preocupação, com, qualidade, ...
# 4      [Não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [Muito, bom, amei, esse, app]
# 35978                                       [Muito, bom]
# 35979                        [Ótimo, pra, todo, momento]
# 35980                                              [Top]
# 35981  [Incrível, ,, sempre, tem, bons, resultados, e...
#
#                                         tokens_lowercase  \
# 0      [fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [informações, do, produto, e, imagens, sem, cl...
# 2      [uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [não, tem, mais, preocupação, com, qualidade, ...
# 4      [não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [muito, bom, amei, esse, app]
# 35978                                       [muito, bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, ,, sempre, tem, bons, resultados, e...
#
#                               tokens_without_punctuation
# 0      [fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [informações, do, produto, e, imagens, sem, cl...
# 2      [uso, o, aplicativo, a, um, bom, tempo, porém,...
# 3      [não, tem, mais, preocupação, com, qualidade, ...
# 4      [não, aparece, mais, cupons, a, mais, de, 7, m...
# ...                                                  ...
# 35977                      [muito, bom, amei, esse, app]
# 35978                                       [muito, bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, sempre, tem, bons, resultados, e, a...
#
# [35977 rows x 20 columns]

# %% [markdown]
# ## Removendo stopwords

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = stopwords.words('portuguese')
stop_words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hão',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houverá',
#  'houveram',
#  'houvéramos',
#  'houverão',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveríamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvéssemos',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'não',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nós',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'são',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'será',
#  'serão',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seríamos',
#  'seu',
#  'seus',
#  'só',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'também',
#  'te',
#  'tem',
#  'tém',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terá',
#  'terão',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tínhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tivéramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos']

# %%
len(stop_words)
# Out:
# 207

# %%
stop_words.append('app')
stop_words
# Out:
# ['a',
#  'à',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'às',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'é',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'éramos',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'está',
#  'estamos',
#  'estão',
#  'estar',
#  'estas',
#  'estava',
#  'estavam',
#  'estávamos',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estivéramos',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéssemos',
#  'estou',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'fôramos',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fôssemos',
#  'fui',
#  'há',
#  'haja',
#  'hajam',
#  'hajamos',
#  'hão',
#  'havemos',
#  'haver',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houverá',
#  'houveram',
#  'houvéramos',
#  'houverão',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houveríamos',
#  'houvermos',
#  'houvesse',
#  'houvessem',
#  'houvéssemos',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'não',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nós',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'são',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'ser',
#  'será',
#  'serão',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'seríamos',
#  'seu',
#  'seus',
#  'só',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'também',
#  'te',
#  'tem',
#  'tém',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terá',
#  'terão',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tínhamos',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tivéramos',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos',
#  'app']

# %%
def remove_stopwords(tokens):
  tokens_without_stopwords = [token for token in tokens if token not in stop_words]
  return tokens_without_stopwords

df['tokens_without_stopwords'] = df['tokens_without_punctuation'].apply(remove_stopwords)
df
# Out:
# <ipython-input-39-f324757cb345>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tokens_without_stopwords'] = df['tokens_without_punctuation'].apply(remove_stopwords)
#        Unnamed: 0                              reviewId  \
# 0               0  2cf8d528-4be9-4582-8029-b12c7853ba9c
# 1               1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50
# 2               2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1
# 3               3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15
# 4               4  9c203cc4-289f-46cf-b55a-6332791b3b8c
# ...           ...                                   ...
# 35977       35977  785b13d8-ccc9-4629-b844-557f90d4d734
# 35978       35978  c2121839-7857-49c9-9609-27aed288d297
# 35979       35979  b5286f42-23a0-408c-9fc4-5c0f069e950a
# 35980       35980  b31c7352-1b90-4caf-81d7-e0e2ae9b44d5
# 35981       35981  befb72c1-8a35-4c09-8094-44a2278cd8a3
#
#                      userName  \
# 0             Daniela Aguilar
# 1      Arlan Cruz (Miguelito)
# 2             Gabriel Liondas
# 3                Ester Araújo
# 4                     Adr_Alv
# ...                       ...
# 35977            Lais De Lima
# 35978             Marta Silva
# 35979               Bp Santos
# 35980             Mauro Cesar
# 35981          Fernando Silva
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 35977  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35978  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35979  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35980  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35981  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...      1
# 1      Informações do produto e imagens sem clareza. ...      1
# 2      Uso o aplicativo a um bom tempo, porém, tive u...      1
# 3      Não tem mais preocupação com qualidade. Os ent...      1
# 4      Não aparece mais cupons, a mais de 7 meses par...      1
# ...                                                  ...    ...
# 35977                            Muito bom amei esse app      5
# 35978                                          Muito bom      5
# 35979             Ótimo pra todo momento www.aiqfome.com      5
# 35980                                             Top 🤝🏻      5
# 35981  Incrível , sempre tem bons resultados e as mel...      5
#
#        thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 0                252              9.223.0  2023-09-09 02:48:00          NaN
# 1                173              9.223.0  2023-09-10 00:24:00          NaN
# 2                 12              9.222.1  2023-09-09 16:46:25          NaN
# 3                 32              9.221.0  2023-08-31 21:14:46          NaN
# 4                 14              9.222.1  2023-09-08 14:40:36          NaN
# ...              ...                  ...                  ...          ...
# 35977              0               10.0.0  2023-07-15 18:45:03          NaN
# 35978              0               10.0.0  2023-07-15 15:56:29          NaN
# 35979              0               10.0.0  2023-07-15 03:09:38          NaN
# 35980              0               10.0.0  2023-07-15 00:42:34          NaN
# 35981              0                  NaN  2023-07-15 00:06:39          NaN
#
#        ... appVersion      sortOrder                  appId word_count  \
# 0      ...    9.223.0  most_relevant  br.com.brainweb.ifood         81
# 1      ...    9.223.0  most_relevant  br.com.brainweb.ifood         77
# 2      ...    9.222.1  most_relevant  br.com.brainweb.ifood         71
# 3      ...    9.221.0  most_relevant  br.com.brainweb.ifood         55
# 4      ...    9.222.1  most_relevant  br.com.brainweb.ifood         95
# ...    ...        ...            ...                    ...        ...
# 35977  ...     10.0.0         newest    com.vanuatu.aiqfome          5
# 35978  ...     10.0.0         newest    com.vanuatu.aiqfome          2
# 35979  ...     10.0.0         newest    com.vanuatu.aiqfome          5
# 35980  ...     10.0.0         newest    com.vanuatu.aiqfome          2
# 35981  ...        NaN         newest    com.vanuatu.aiqfome         28
#
#                                            removed_emoji  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979             Ótimo pra todo momento www.aiqfome.com
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                            removed_links  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979                            Ótimo pra todo momento
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                                   tokens  \
# 0      [Fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [Informações, do, produto, e, imagens, sem, cl...
# 2      [Uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [Não, tem, mais, preocupação, com, qualidade, ...
# 4      [Não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [Muito, bom, amei, esse, app]
# 35978                                       [Muito, bom]
# 35979                        [Ótimo, pra, todo, momento]
# 35980                                              [Top]
# 35981  [Incrível, ,, sempre, tem, bons, resultados, e...
#
#                                         tokens_lowercase  \
# 0      [fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [informações, do, produto, e, imagens, sem, cl...
# 2      [uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [não, tem, mais, preocupação, com, qualidade, ...
# 4      [não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [muito, bom, amei, esse, app]
# 35978                                       [muito, bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, ,, sempre, tem, bons, resultados, e...
#
#                               tokens_without_punctuation  \
# 0      [fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [informações, do, produto, e, imagens, sem, cl...
# 2      [uso, o, aplicativo, a, um, bom, tempo, porém,...
# 3      [não, tem, mais, preocupação, com, qualidade, ...
# 4      [não, aparece, mais, cupons, a, mais, de, 7, m...
# ...                                                  ...
# 35977                      [muito, bom, amei, esse, app]
# 35978                                       [muito, bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, sempre, tem, bons, resultados, e, a...
#
#                                 tokens_without_stopwords
# 0      [fiz, pedido, veio, item, faltando, tentar, re...
# 1      [informações, produto, imagens, clareza, lojas...
# 2      [uso, aplicativo, bom, tempo, porém, problema,...
# 3      [preocupação, qualidade, entregadores, atrasam...
# 4      [aparece, cupons, 7, meses, específico, restau...
# ...                                                  ...
# 35977                                        [bom, amei]
# 35978                                              [bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, sempre, bons, resultados, melhores,...
#
# [35977 rows x 21 columns]

# %% [markdown]
# ## Obtendo radicais

# %%
from nltk.stem import RSLPStemmer
nltk.download('rslp')

def stemmer_tokens(tokens):
  stemmer = RSLPStemmer()
  stemmed_tokens = [stemmer.stem(token) for token in tokens]
  return ' '.join(stemmed_tokens)

df['stemmed_tokens'] = df['tokens_without_stopwords'].apply(stemmer_tokens)
df
# Out:
# [nltk_data] Downloading package rslp to /root/nltk_data...
# [nltk_data]   Unzipping stemmers/rslp.zip.
# <ipython-input-40-27b032ef0c6e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['stemmed_tokens'] = df['tokens_without_stopwords'].apply(stemmer_tokens)
#        Unnamed: 0                              reviewId  \
# 0               0  2cf8d528-4be9-4582-8029-b12c7853ba9c
# 1               1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50
# 2               2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1
# 3               3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15
# 4               4  9c203cc4-289f-46cf-b55a-6332791b3b8c
# ...           ...                                   ...
# 35977       35977  785b13d8-ccc9-4629-b844-557f90d4d734
# 35978       35978  c2121839-7857-49c9-9609-27aed288d297
# 35979       35979  b5286f42-23a0-408c-9fc4-5c0f069e950a
# 35980       35980  b31c7352-1b90-4caf-81d7-e0e2ae9b44d5
# 35981       35981  befb72c1-8a35-4c09-8094-44a2278cd8a3
#
#                      userName  \
# 0             Daniela Aguilar
# 1      Arlan Cruz (Miguelito)
# 2             Gabriel Liondas
# 3                Ester Araújo
# 4                     Adr_Alv
# ...                       ...
# 35977            Lais De Lima
# 35978             Marta Silva
# 35979               Bp Santos
# 35980             Mauro Cesar
# 35981          Fernando Silva
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 35977  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35978  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35979  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35980  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35981  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...      1
# 1      Informações do produto e imagens sem clareza. ...      1
# 2      Uso o aplicativo a um bom tempo, porém, tive u...      1
# 3      Não tem mais preocupação com qualidade. Os ent...      1
# 4      Não aparece mais cupons, a mais de 7 meses par...      1
# ...                                                  ...    ...
# 35977                            Muito bom amei esse app      5
# 35978                                          Muito bom      5
# 35979             Ótimo pra todo momento www.aiqfome.com      5
# 35980                                             Top 🤝🏻      5
# 35981  Incrível , sempre tem bons resultados e as mel...      5
#
#        thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 0                252              9.223.0  2023-09-09 02:48:00          NaN
# 1                173              9.223.0  2023-09-10 00:24:00          NaN
# 2                 12              9.222.1  2023-09-09 16:46:25          NaN
# 3                 32              9.221.0  2023-08-31 21:14:46          NaN
# 4                 14              9.222.1  2023-09-08 14:40:36          NaN
# ...              ...                  ...                  ...          ...
# 35977              0               10.0.0  2023-07-15 18:45:03          NaN
# 35978              0               10.0.0  2023-07-15 15:56:29          NaN
# 35979              0               10.0.0  2023-07-15 03:09:38          NaN
# 35980              0               10.0.0  2023-07-15 00:42:34          NaN
# 35981              0                  NaN  2023-07-15 00:06:39          NaN
#
#        ...      sortOrder                  appId word_count  \
# 0      ...  most_relevant  br.com.brainweb.ifood         81
# 1      ...  most_relevant  br.com.brainweb.ifood         77
# 2      ...  most_relevant  br.com.brainweb.ifood         71
# 3      ...  most_relevant  br.com.brainweb.ifood         55
# 4      ...  most_relevant  br.com.brainweb.ifood         95
# ...    ...            ...                    ...        ...
# 35977  ...         newest    com.vanuatu.aiqfome          5
# 35978  ...         newest    com.vanuatu.aiqfome          2
# 35979  ...         newest    com.vanuatu.aiqfome          5
# 35980  ...         newest    com.vanuatu.aiqfome          2
# 35981  ...         newest    com.vanuatu.aiqfome         28
#
#                                            removed_emoji  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979             Ótimo pra todo momento www.aiqfome.com
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                            removed_links  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979                            Ótimo pra todo momento
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                                   tokens  \
# 0      [Fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [Informações, do, produto, e, imagens, sem, cl...
# 2      [Uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [Não, tem, mais, preocupação, com, qualidade, ...
# 4      [Não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [Muito, bom, amei, esse, app]
# 35978                                       [Muito, bom]
# 35979                        [Ótimo, pra, todo, momento]
# 35980                                              [Top]
# 35981  [Incrível, ,, sempre, tem, bons, resultados, e...
#
#                                         tokens_lowercase  \
# 0      [fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [informações, do, produto, e, imagens, sem, cl...
# 2      [uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [não, tem, mais, preocupação, com, qualidade, ...
# 4      [não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [muito, bom, amei, esse, app]
# 35978                                       [muito, bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, ,, sempre, tem, bons, resultados, e...
#
#                               tokens_without_punctuation  \
# 0      [fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [informações, do, produto, e, imagens, sem, cl...
# 2      [uso, o, aplicativo, a, um, bom, tempo, porém,...
# 3      [não, tem, mais, preocupação, com, qualidade, ...
# 4      [não, aparece, mais, cupons, a, mais, de, 7, m...
# ...                                                  ...
# 35977                      [muito, bom, amei, esse, app]
# 35978                                       [muito, bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, sempre, tem, bons, resultados, e, a...
#
#                                 tokens_without_stopwords  \
# 0      [fiz, pedido, veio, item, faltando, tentar, re...
# 1      [informações, produto, imagens, clareza, lojas...
# 2      [uso, aplicativo, bom, tempo, porém, problema,...
# 3      [preocupação, qualidade, entregadores, atrasam...
# 4      [aparece, cupons, 7, meses, específico, restau...
# ...                                                  ...
# 35977                                        [bom, amei]
# 35978                                              [bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, sempre, bons, resultados, melhores,...
#
#                                           stemmed_tokens
# 0      fiz ped vei it falt tent report err aba `` aju...
# 1      inform produt imag clar loj ag cancel ped conv...
# 2      uso aplic bom temp porém problem ped recent do...
# 3      preocup qual entreg atras demal entreg ped ain...
# 4      aparec cupom 7 mes específ restaurant impõ pre...
# ...                                                  ...
# 35977                                            bom ame
# 35978                                                bom
# 35979                                ótim pra tod moment
# 35980                                                top
# 35981  incr sempr bom result melhor escolh parc tá in...
#
# [35977 rows x 22 columns]

# %% [markdown]
# ## Compilando todas as funções de pré-processamento

# %%
def process_text(text):
  text = remove_emojis(text)
  text = remove_link(text)
  tokens = tokenize_text(text)
  tokens = lowercase(tokens)
  tokens = remove_punctuation(tokens)
  tokens = remove_stopwords(tokens)
  processed_text = stemmer_tokens(tokens)

  return processed_text

# %%
text = "Hoje o dia está maravilhoso"
process_text(text)
# Out:
# 'hoj dia maravilh'

# %% [markdown]
# ## Convertendo scores em sentimentos

# %%
def to_sentiment(score):
  score = int(score)
  if score >= 4:
    return 'Positive'
  else:
    return 'Negative'

df['sentiment'] = df['score'].apply(to_sentiment)
df
# Out:
# <ipython-input-43-66b656e85648>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment'] = df['score'].apply(to_sentiment)
#        Unnamed: 0                              reviewId  \
# 0               0  2cf8d528-4be9-4582-8029-b12c7853ba9c
# 1               1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50
# 2               2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1
# 3               3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15
# 4               4  9c203cc4-289f-46cf-b55a-6332791b3b8c
# ...           ...                                   ...
# 35977       35977  785b13d8-ccc9-4629-b844-557f90d4d734
# 35978       35978  c2121839-7857-49c9-9609-27aed288d297
# 35979       35979  b5286f42-23a0-408c-9fc4-5c0f069e950a
# 35980       35980  b31c7352-1b90-4caf-81d7-e0e2ae9b44d5
# 35981       35981  befb72c1-8a35-4c09-8094-44a2278cd8a3
#
#                      userName  \
# 0             Daniela Aguilar
# 1      Arlan Cruz (Miguelito)
# 2             Gabriel Liondas
# 3                Ester Araújo
# 4                     Adr_Alv
# ...                       ...
# 35977            Lais De Lima
# 35978             Marta Silva
# 35979               Bp Santos
# 35980             Mauro Cesar
# 35981          Fernando Silva
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 35977  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35978  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35979  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35980  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35981  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...      1
# 1      Informações do produto e imagens sem clareza. ...      1
# 2      Uso o aplicativo a um bom tempo, porém, tive u...      1
# 3      Não tem mais preocupação com qualidade. Os ent...      1
# 4      Não aparece mais cupons, a mais de 7 meses par...      1
# ...                                                  ...    ...
# 35977                            Muito bom amei esse app      5
# 35978                                          Muito bom      5
# 35979             Ótimo pra todo momento www.aiqfome.com      5
# 35980                                             Top 🤝🏻      5
# 35981  Incrível , sempre tem bons resultados e as mel...      5
#
#        thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 0                252              9.223.0  2023-09-09 02:48:00          NaN
# 1                173              9.223.0  2023-09-10 00:24:00          NaN
# 2                 12              9.222.1  2023-09-09 16:46:25          NaN
# 3                 32              9.221.0  2023-08-31 21:14:46          NaN
# 4                 14              9.222.1  2023-09-08 14:40:36          NaN
# ...              ...                  ...                  ...          ...
# 35977              0               10.0.0  2023-07-15 18:45:03          NaN
# 35978              0               10.0.0  2023-07-15 15:56:29          NaN
# 35979              0               10.0.0  2023-07-15 03:09:38          NaN
# 35980              0               10.0.0  2023-07-15 00:42:34          NaN
# 35981              0                  NaN  2023-07-15 00:06:39          NaN
#
#        ...                  appId word_count  \
# 0      ...  br.com.brainweb.ifood         81
# 1      ...  br.com.brainweb.ifood         77
# 2      ...  br.com.brainweb.ifood         71
# 3      ...  br.com.brainweb.ifood         55
# 4      ...  br.com.brainweb.ifood         95
# ...    ...                    ...        ...
# 35977  ...    com.vanuatu.aiqfome          5
# 35978  ...    com.vanuatu.aiqfome          2
# 35979  ...    com.vanuatu.aiqfome          5
# 35980  ...    com.vanuatu.aiqfome          2
# 35981  ...    com.vanuatu.aiqfome         28
#
#                                            removed_emoji  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979             Ótimo pra todo momento www.aiqfome.com
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                            removed_links  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979                            Ótimo pra todo momento
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                                   tokens  \
# 0      [Fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [Informações, do, produto, e, imagens, sem, cl...
# 2      [Uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [Não, tem, mais, preocupação, com, qualidade, ...
# 4      [Não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [Muito, bom, amei, esse, app]
# 35978                                       [Muito, bom]
# 35979                        [Ótimo, pra, todo, momento]
# 35980                                              [Top]
# 35981  [Incrível, ,, sempre, tem, bons, resultados, e...
#
#                                         tokens_lowercase  \
# 0      [fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [informações, do, produto, e, imagens, sem, cl...
# 2      [uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [não, tem, mais, preocupação, com, qualidade, ...
# 4      [não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [muito, bom, amei, esse, app]
# 35978                                       [muito, bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, ,, sempre, tem, bons, resultados, e...
#
#                               tokens_without_punctuation  \
# 0      [fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [informações, do, produto, e, imagens, sem, cl...
# 2      [uso, o, aplicativo, a, um, bom, tempo, porém,...
# 3      [não, tem, mais, preocupação, com, qualidade, ...
# 4      [não, aparece, mais, cupons, a, mais, de, 7, m...
# ...                                                  ...
# 35977                      [muito, bom, amei, esse, app]
# 35978                                       [muito, bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, sempre, tem, bons, resultados, e, a...
#
#                                 tokens_without_stopwords  \
# 0      [fiz, pedido, veio, item, faltando, tentar, re...
# 1      [informações, produto, imagens, clareza, lojas...
# 2      [uso, aplicativo, bom, tempo, porém, problema,...
# 3      [preocupação, qualidade, entregadores, atrasam...
# 4      [aparece, cupons, 7, meses, específico, restau...
# ...                                                  ...
# 35977                                        [bom, amei]
# 35978                                              [bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, sempre, bons, resultados, melhores,...
#
#                                           stemmed_tokens sentiment
# 0      fiz ped vei it falt tent report err aba `` aju...  Negative
# 1      inform produt imag clar loj ag cancel ped conv...  Negative
# 2      uso aplic bom temp porém problem ped recent do...  Negative
# 3      preocup qual entreg atras demal entreg ped ain...  Negative
# 4      aparec cupom 7 mes específ restaurant impõ pre...  Negative
# ...                                                  ...       ...
# 35977                                            bom ame  Positive
# 35978                                                bom  Positive
# 35979                                ótim pra tod moment  Positive
# 35980                                                top  Positive
# 35981  incr sempr bom result melhor escolh parc tá in...  Positive
#
# [35977 rows x 23 columns]

# %% [markdown]
# ## Reavaliando os dados

# %%
data_analytics(df, 'stemmed_tokens', 'sentiment')
# Out:
# Número de nulos por coluna:
#
# Unnamed: 0                        0
# reviewId                          0
# userName                          0
# userImage                         0
# content                           0
# score                             0
# thumbsUpCount                     0
# reviewCreatedVersion           3361
# at                                0
# replyContent                  27016
# repliedAt                     27016
# appVersion                     3361
# sortOrder                         0
# appId                             0
# word_count                        0
# removed_emoji                     0
# removed_links                     0
# tokens                            0
# tokens_lowercase                  0
# tokens_without_punctuation        0
# tokens_without_stopwords          0
# stemmed_tokens                    0
# sentiment                         0
# dtype: int64
#
# O número mínimo de palavras no dataset é: 0
# A média de palavras no dataset é: 15.769852961614365
# O número máximo de palavras no dataset é: 102
#
# Histograma da frequência do número de palavras
# <ipython-input-11-159c2fb5bc83>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['word_count'] = df[text_column].str.split().apply(len)
# Número de instâncias por classe
# Positive    17999
# Negative    17978
# Name: sentiment, dtype: int64
#
# Histograma da distribuição das classes
# Gráfico de pizza da distribuição das classes
# Palavras mais frequentes
#   Palavra  Frequência
# 0     ped       14305
# 1  entreg        9629
# 2   aplic        8419
# 3     bom        7151
# 4     pag        6433
# 5     pra        5437
# 6     vez        5296
# 7   compr        5291
# 8   cupom        4830
# 9     opç        4702
# Palavras mais frequentes para a classe Negative
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0     ped       10086
# 1  entreg        5709
# 2   aplic        5190
# 3     pag        4547
# 4   compr        3698
# 5     pra        3681
# 6     faz        3276
# 7     vez        3272
# 8   cupom        2818
# 9  cancel        2648
# Palavras mais frequentes para a classe Positive
#
# Palavras mais frequentes
#   Palavra  Frequência
# 0     bom        5025
# 1     ped        4219
# 2  entreg        3920
# 3   aplic        3229
# 4  melhor        2473
# 5    ótim        2243
# 6     opç        2188
# 7     vez        2024
# 8   cupom        2012
# 9     pod        1984
# WordCloud

# %%
def join_tokens(tokens):
  return ' '.join(tokens)

df['text_clean'] = df['tokens_without_stopwords'].apply(join_tokens)
# Out:
# <ipython-input-45-27514d9867c9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_clean'] = df['tokens_without_stopwords'].apply(join_tokens)

# %%
data_analytics(df, 'text_clean', 'sentiment')
# Out:
# Número de nulos por coluna:
#
# Unnamed: 0                        0
# reviewId                          0
# userName                          0
# userImage                         0
# content                           0
# score                             0
# thumbsUpCount                     0
# reviewCreatedVersion           3361
# at                                0
# replyContent                  27016
# repliedAt                     27016
# appVersion                     3361
# sortOrder                         0
# appId                             0
# word_count                        0
# removed_emoji                     0
# removed_links                     0
# tokens                            0
# tokens_lowercase                  0
# tokens_without_punctuation        0
# tokens_without_stopwords          0
# stemmed_tokens                    0
# sentiment                         0
# text_clean                        0
# dtype: int64
#
# O número mínimo de palavras no dataset é: 0
# A média de palavras no dataset é: 15.769852961614365
# O número máximo de palavras no dataset é: 102
#
# Histograma da frequência do número de palavras
# <ipython-input-11-159c2fb5bc83>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['word_count'] = df[text_column].str.split().apply(len)
# Número de instâncias por classe
# Positive    17999
# Negative    17978
# Name: sentiment, dtype: int64
#
# Histograma da distribuição das classes
# Gráfico de pizza da distribuição das classes
# Palavras mais frequentes
#       Palavra  Frequência
# 0      pedido        9165
# 1  aplicativo        7808
# 2         bom        6753
# 3         pra        5350
# 4     entrega        5009
# 5      sempre        3400
# 6       vezes        3394
# 7         ...        3258
# 8       opção        3184
# 9   pagamento        3056
# Palavras mais frequentes para a classe Negative
#
# Palavras mais frequentes
#       Palavra  Frequência
# 0      pedido        6689
# 1  aplicativo        4817
# 2         pra        3655
# 3     entrega        2794
# 4   pagamento        2114
# 5       fazer        2099
# 6         ...        2088
# 7      cartão        2005
# 8         bom        1986
# 9       vezes        1950
# Palavras mais frequentes para a classe Positive
#
# Palavras mais frequentes
#       Palavra  Frequência
# 0         bom        4767
# 1  aplicativo        2991
# 2      pedido        2476
# 3     entrega        2215
# 4         bem        1745
# 5         pra        1695
# 6      sempre        1695
# 7       ótimo        1644
# 8       vezes        1444
# 9      cupons        1384
# WordCloud

# %%
df = df[df['word_count'] > 0]
df
# Out:
#        Unnamed: 0                              reviewId  \
# 0               0  2cf8d528-4be9-4582-8029-b12c7853ba9c
# 1               1  a0aefee6-4c2b-4d87-86d6-45ea111dcf50
# 2               2  4b28558b-23e9-4e14-96b6-6e0e936f1ff1
# 3               3  a7d610c9-30aa-4f8b-9a14-142ca9ec3b15
# 4               4  9c203cc4-289f-46cf-b55a-6332791b3b8c
# ...           ...                                   ...
# 35977       35977  785b13d8-ccc9-4629-b844-557f90d4d734
# 35978       35978  c2121839-7857-49c9-9609-27aed288d297
# 35979       35979  b5286f42-23a0-408c-9fc4-5c0f069e950a
# 35980       35980  b31c7352-1b90-4caf-81d7-e0e2ae9b44d5
# 35981       35981  befb72c1-8a35-4c09-8094-44a2278cd8a3
#
#                      userName  \
# 0             Daniela Aguilar
# 1      Arlan Cruz (Miguelito)
# 2             Gabriel Liondas
# 3                Ester Araújo
# 4                     Adr_Alv
# ...                       ...
# 35977            Lais De Lima
# 35978             Marta Silva
# 35979               Bp Santos
# 35980             Mauro Cesar
# 35981          Fernando Silva
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ALV-U...
# 1      https://play-lh.googleusercontent.com/a-/ALV-U...
# 2      https://play-lh.googleusercontent.com/a-/ALV-U...
# 3      https://play-lh.googleusercontent.com/a-/ALV-U...
# 4      https://play-lh.googleusercontent.com/a-/ALV-U...
# ...                                                  ...
# 35977  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35978  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35979  https://play-lh.googleusercontent.com/a/ACg8oc...
# 35980  https://play-lh.googleusercontent.com/a-/ALV-U...
# 35981  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                  content  score  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...      1
# 1      Informações do produto e imagens sem clareza. ...      1
# 2      Uso o aplicativo a um bom tempo, porém, tive u...      1
# 3      Não tem mais preocupação com qualidade. Os ent...      1
# 4      Não aparece mais cupons, a mais de 7 meses par...      1
# ...                                                  ...    ...
# 35977                            Muito bom amei esse app      5
# 35978                                          Muito bom      5
# 35979             Ótimo pra todo momento www.aiqfome.com      5
# 35980                                             Top 🤝🏻      5
# 35981  Incrível , sempre tem bons resultados e as mel...      5
#
#        thumbsUpCount reviewCreatedVersion                   at replyContent  \
# 0                252              9.223.0  2023-09-09 02:48:00          NaN
# 1                173              9.223.0  2023-09-10 00:24:00          NaN
# 2                 12              9.222.1  2023-09-09 16:46:25          NaN
# 3                 32              9.221.0  2023-08-31 21:14:46          NaN
# 4                 14              9.222.1  2023-09-08 14:40:36          NaN
# ...              ...                  ...                  ...          ...
# 35977              0               10.0.0  2023-07-15 18:45:03          NaN
# 35978              0               10.0.0  2023-07-15 15:56:29          NaN
# 35979              0               10.0.0  2023-07-15 03:09:38          NaN
# 35980              0               10.0.0  2023-07-15 00:42:34          NaN
# 35981              0                  NaN  2023-07-15 00:06:39          NaN
#
#        ... word_count                                      removed_emoji  \
# 0      ...         41  Fiz um pedido e veio com um item faltando. Ao ...
# 1      ...         43  Informações do produto e imagens sem clareza. ...
# 2      ...         42  Uso o aplicativo a um bom tempo, porém, tive u...
# 3      ...         25  Não tem mais preocupação com qualidade. Os ent...
# 4      ...         49  Não aparece mais cupons, a mais de 7 meses par...
# ...    ...        ...                                                ...
# 35977  ...          2                            Muito bom amei esse app
# 35978  ...          1                                          Muito bom
# 35979  ...          4             Ótimo pra todo momento www.aiqfome.com
# 35980  ...          1                                               Top
# 35981  ...         14  Incrível , sempre tem bons resultados e as mel...
#
#                                            removed_links  \
# 0      Fiz um pedido e veio com um item faltando. Ao ...
# 1      Informações do produto e imagens sem clareza. ...
# 2      Uso o aplicativo a um bom tempo, porém, tive u...
# 3      Não tem mais preocupação com qualidade. Os ent...
# 4      Não aparece mais cupons, a mais de 7 meses par...
# ...                                                  ...
# 35977                            Muito bom amei esse app
# 35978                                          Muito bom
# 35979                            Ótimo pra todo momento
# 35980                                               Top
# 35981  Incrível , sempre tem bons resultados e as mel...
#
#                                                   tokens  \
# 0      [Fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [Informações, do, produto, e, imagens, sem, cl...
# 2      [Uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [Não, tem, mais, preocupação, com, qualidade, ...
# 4      [Não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [Muito, bom, amei, esse, app]
# 35978                                       [Muito, bom]
# 35979                        [Ótimo, pra, todo, momento]
# 35980                                              [Top]
# 35981  [Incrível, ,, sempre, tem, bons, resultados, e...
#
#                                         tokens_lowercase  \
# 0      [fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [informações, do, produto, e, imagens, sem, cl...
# 2      [uso, o, aplicativo, a, um, bom, tempo, ,, por...
# 3      [não, tem, mais, preocupação, com, qualidade, ...
# 4      [não, aparece, mais, cupons, ,, a, mais, de, 7...
# ...                                                  ...
# 35977                      [muito, bom, amei, esse, app]
# 35978                                       [muito, bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, ,, sempre, tem, bons, resultados, e...
#
#                               tokens_without_punctuation  \
# 0      [fiz, um, pedido, e, veio, com, um, item, falt...
# 1      [informações, do, produto, e, imagens, sem, cl...
# 2      [uso, o, aplicativo, a, um, bom, tempo, porém,...
# 3      [não, tem, mais, preocupação, com, qualidade, ...
# 4      [não, aparece, mais, cupons, a, mais, de, 7, m...
# ...                                                  ...
# 35977                      [muito, bom, amei, esse, app]
# 35978                                       [muito, bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, sempre, tem, bons, resultados, e, a...
#
#                                 tokens_without_stopwords  \
# 0      [fiz, pedido, veio, item, faltando, tentar, re...
# 1      [informações, produto, imagens, clareza, lojas...
# 2      [uso, aplicativo, bom, tempo, porém, problema,...
# 3      [preocupação, qualidade, entregadores, atrasam...
# 4      [aparece, cupons, 7, meses, específico, restau...
# ...                                                  ...
# 35977                                        [bom, amei]
# 35978                                              [bom]
# 35979                        [ótimo, pra, todo, momento]
# 35980                                              [top]
# 35981  [incrível, sempre, bons, resultados, melhores,...
#
#                                           stemmed_tokens sentiment  \
# 0      fiz ped vei it falt tent report err aba `` aju...  Negative
# 1      inform produt imag clar loj ag cancel ped conv...  Negative
# 2      uso aplic bom temp porém problem ped recent do...  Negative
# 3      preocup qual entreg atras demal entreg ped ain...  Negative
# 4      aparec cupom 7 mes específ restaurant impõ pre...  Negative
# ...                                                  ...       ...
# 35977                                            bom ame  Positive
# 35978                                                bom  Positive
# 35979                                ótim pra tod moment  Positive
# 35980                                                top  Positive
# 35981  incr sempr bom result melhor escolh parc tá in...  Positive
#
#                                               text_clean
# 0      fiz pedido veio item faltando tentar reportar ...
# 1      informações produto imagens clareza lojas agem...
# 2      uso aplicativo bom tempo porém problema pedido...
# 3      preocupação qualidade entregadores atrasam dem...
# 4      aparece cupons 7 meses específico restaurantes...
# ...                                                  ...
# 35977                                           bom amei
# 35978                                                bom
# 35979                             ótimo pra todo momento
# 35980                                                top
# 35981  incrível sempre bons resultados melhores escol...
#
# [35864 rows x 24 columns]

# %% [markdown]
# # Representando os dados numericamente

# %% [markdown]
# ## Dividindo o conjunto de dados em treinamento e teste

# %%
from sklearn.model_selection import train_test_split

seed = 42

x_train, x_test, y_train, y_test = train_test_split(df['stemmed_tokens'], df['sentiment'], test_size = 0.3, stratify = df['sentiment'], random_state = seed)

# %%
len(x_train)
# Out:
# 25104

# %%
len(x_test)
# Out:
# 10760

# %% [markdown]
# ## Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer

bag_of_words = CountVectorizer()
x_train_num = bag_of_words.fit_transform(x_train)
x_test_num = bag_of_words.transform(x_test)

# %%
x_train_num
# Out:
# <25104x9520 sparse matrix of type '<class 'numpy.int64'>'
# 	with 349654 stored elements in Compressed Sparse Row format>
